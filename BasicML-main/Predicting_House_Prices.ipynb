# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahsalo/BasicML/blob/main/Predicting_House_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
def house_model(y_new):
    xs = np.array([1,2,3,5,8,10])
    ys = np.array([1,1.5,2,3,4.5,5.5])
    model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
    model.compile(optimizer='sgd',loss='mean_squared_error')
    model.fit(xs,ys,epochs=100)
    return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
print(prediction)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 449ms/step - loss: 112.8518
# Epoch 2/100
# 1/1 [==============================] - 0s 3ms/step - loss: 10.8192
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0517
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1165
# Epoch 5/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0268
# Epoch 6/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0180
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0170
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0167
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0165
# Epoch 10/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0161
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0159
# ...
